# %% [markdown]
# Dummy Notebook...

# %%
print("First Jupyter Python notebook")
# Out:
# First Jupyter Python notebook

# %%
a = 2
b = 3

# %%
print(a, b)
# Out:
# 2 3

# %%
a+b
# Out:
# 5

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
plt.plot(x,y, 'r*')
plt.plot(x, y)
plt.title("Squared relation")
plt.xlabel("Values of X")
plt.ylabel("Values of Y")
# Out:
# Text(0, 0.5, 'Values of Y')

# %% [markdown]
# **OOP Approach**

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1, 0.8,0.8])
axes2 = fig.add_axes([0.23, 0.45,0.35,0.35])
axes.set_xlabel("Values of X")
axes.set_ylabel("Values of Y")
axes.set_title('Squared Relations')
axes.plot(x,y)
axes2.set_xlabel("Values of X")
axes2.set_ylabel("Values of Y")
axes2.set_title('Squared Relations)
axes2.plot(x,y, 'g-')b

# %%
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.barplot(x =y, y=x)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.bar(x,y);
plt.plot(x,y,color='g');
plt.xticks(rotation=0)
plt.xlabel('Top 10 Bowlers')
plt.ylabel('Wickets Taken')
plt.title('Top 10 Bowlers in last 12 seasons');
